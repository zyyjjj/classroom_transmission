# %%
import sys
sys.path.append('..')

from src.run_regression import run_cox_regression, run_gee_logistic_regression, export_cox_result, export_logistic_result

# %% [markdown]
# ## Fall 2021

# %%
cox_fa21 = run_cox_regression(semester="fa21",verbose=True)
# Out:
# c:\Program Files\Python37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ..\src\run_regression.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
# Iteration 1: norm_delta = 8.48e-02, step_size = 0.1000, log_lik = -5909.25482, newton_decrement = 2.45e+02, seconds_since_start = 1.6
# Iteration 2: norm_delta = 6.44e-02, step_size = 0.1000, log_lik = -5862.85619, newton_decrement = 1.59e+02, seconds_since_start = 3.2
# ...

# %%
export_cox_result(cox_fa21).to_csv("../results/cox_fa21.csv", float_format="%.2f")

# %%
# not feasible to control by day
logistic_fa21 = run_gee_logistic_regression(semester="fa21")
# Out:
# c:\Program Files\Python37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ..\src\run_regression.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
# C:\Users\yz685\AppData\Roaming\Python\Python37\site-packages\statsmodels\genmod\families\links.py:187: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# C:\Users\yz685\AppData\Roaming\Python\Python37\site-packages\statsmodels\genmod\families\links.py:228: RuntimeWarning: overflow encountered in exp
#   t = np.exp(z)
# ...

# %%
# instead try controlling for week and include campus positivity
logistic_fa21 = run_gee_logistic_regression(semester="fa21", by="week")
# Out:
# c:\Program Files\Python37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ..\src\run_regression.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
#                                GEE Regression Results
# ...
# Dep. Variable:        infected_on_this_day   No. Observations:              1771641
# Model:                                 GEE   No. clusters:                    17479
# Method:                        Generalized   Min. cluster size:                   2
# ...

# %%
export_logistic_result(logistic_fa21).to_csv("../results/logistic_fa21.csv", float_format="%.2f")

# %% [markdown]
# ## Spring 2022

# %%
cox_sp22 = run_cox_regression(semester="sp22",verbose=True)
# Out:
# ..\src\run_regression.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
# Iteration 1: norm_delta = 4.58e-02, step_size = 0.1000, log_lik = -1844.28387, newton_decrement = 2.22e+01, seconds_since_start = 0.1
# Iteration 2: norm_delta = 3.82e-02, step_size = 0.1000, log_lik = -1840.07136, newton_decrement = 1.67e+01, seconds_since_start = 0.1
# Iteration 3: norm_delta = 3.26e-02, step_size = 0.1000, log_lik = -1836.90758, newton_decrement = 1.28e+01, seconds_since_start = 0.2
# Iteration 4: norm_delta = 3.67e-02, step_size = 0.1300, log_lik = -1834.48207, newton_decrement = 9.94e+00, seconds_since_start = 0.2
# ...

# %%
export_cox_result(cox_sp22).to_csv("../results/cox_sp22.csv", float_format="%.2f")

# %%
logistic_sp22 = run_gee_logistic_regression(semester="sp22")
# Out:
# ..\src\run_regression.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
#                                GEE Regression Results
# ...
# Dep. Variable:        infected_on_this_day   No. Observations:               163161
# Model:                                 GEE   No. clusters:                    11734
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  14
# Family:                           Binomial   Mean cluster size:                13.9
# ...

# %%
export_logistic_result(logistic_sp22).to_csv("../results/logistic_sp22.csv", float_format="%.2f")
