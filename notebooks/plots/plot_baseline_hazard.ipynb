# %%
import sys
sys.path.append('../..')

import matplotlib.pyplot as plt
import numpy as np

from src.run_regression import run_cox_regression

# %% [markdown]
# ## Fall 2021

# %%
cox_fa21, avg_cp = run_cox_regression(semester="fa21",verbose=True)
# Out:
# c:\Program Files\Python37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ../..\src\run_regression.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
# Iteration 1: norm_delta = 8.48e-02, step_size = 0.1000, log_lik = -5909.25482, newton_decrement = 2.45e+02, seconds_since_start = 1.7
# Iteration 2: norm_delta = 6.44e-02, step_size = 0.1000, log_lik = -5862.85619, newton_decrement = 1.59e+02, seconds_since_start = 3.4
# ...

# %%
avg_cp
# Out:
# 0.017824512542531767

# %%
hazard = [0] + [cox_fa21.baseline_cumulative_hazard_.iloc[2]["baseline hazard"]] + \
    list(np.diff(cox_fa21.baseline_cumulative_hazard_.reindex(
        list(range(cox_fa21.baseline_cumulative_hazard_.index.min(),cox_fa21.baseline_cumulative_hazard_.index.max()+1)),method="ffill").values.squeeze(1)
    ))
print(np.mean(hazard))

print(len(hazard))

plt.rcParams["font.family"] = 'Arial'

fig, ax = plt.subplots(figsize = (8, 5))

ax.plot(np.arange(1,105), hazard)
ax.set_title("Fall 2021 study period baseline hazard", fontsize=12, weight='bold')
ax.set_xlabel("Day of study period", fontsize=10)
ax.set_ylabel("Baseline hazard value", fontsize=10)

# fig.savefig("../plots/baseline_hazard_fa21.pdf")
# Out:
# 0.00030648425680267135
# 104
# Text(0, 0.5, 'Baseline hazard value')

# %% [markdown]
# ## Spring 2022

# %%
cox_sp22, avg_cp = run_cox_regression(semester="sp22",verbose=True)
# Out:
# ../..\src\run_regression.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_idx'] = df['day_idx'].apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').toordinal() - baseline_date)
# Iteration 1: norm_delta = 4.58e-02, step_size = 0.1000, log_lik = -1844.28387, newton_decrement = 2.22e+01, seconds_since_start = 0.1
# Iteration 2: norm_delta = 3.82e-02, step_size = 0.1000, log_lik = -1840.07136, newton_decrement = 1.67e+01, seconds_since_start = 0.1
# Iteration 3: norm_delta = 3.26e-02, step_size = 0.1000, log_lik = -1836.90758, newton_decrement = 1.28e+01, seconds_since_start = 0.2
# Iteration 4: norm_delta = 3.67e-02, step_size = 0.1300, log_lik = -1834.48207, newton_decrement = 9.94e+00, seconds_since_start = 0.2
# ...

# %%
hazard = [cox_sp22.baseline_cumulative_hazard_["baseline hazard"].values[0]] + \
    list(np.diff(cox_sp22.baseline_cumulative_hazard_["baseline hazard"].values))
print(np.mean(hazard))

plt.rcParams["font.family"] = 'Arial'

fig, ax = plt.subplots(figsize = (8, 5))

ax.plot(np.arange(1,15), hazard)
ax.set_title("Spring 2022 study period baseline hazard", fontsize=12, weight='bold')
ax.set_xlabel("Day of study period", fontsize=10)
ax.set_ylabel("Baseline hazard value", fontsize=10)

# fig.savefig("../plots/baseline_hazard_sp22.pdf")
# Out:
# 0.0011001284977753157
# Text(0, 0.5, 'Baseline hazard value')
