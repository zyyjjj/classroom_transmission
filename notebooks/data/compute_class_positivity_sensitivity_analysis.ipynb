# %%
import sys
sys.path.append('../..')

import pandas as pd
import datetime as dt
import numpy as np

from src.run_regression import run_cox_regression, run_gee_logistic_regression, export_cox_result, export_logistic_result
from src.compute_class_positivity import compute_class_positivity_fa21, compute_class_positivity_sp22

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time

# %%
for T_e in [3,5,7]:
    for T_a in [3,5,7]:
        if T_e == 7 and T_a == 7:
            continue
        start_time = time.time()
        print(f"compute SP22 class positivity for T_e={T_e} and T_a={T_a}")
        compute_class_positivity_sp22(T_e, T_a)
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# compute SP22 class positivity for T_e=3 and T_a=3
# --- 2249.9907171726227 seconds ---
# compute SP22 class positivity for T_e=3 and T_a=5
# --- 2250.101283788681 seconds ---
# compute SP22 class positivity for T_e=3 and T_a=7
# --- 2270.367465734482 seconds ---
# compute SP22 class positivity for T_e=5 and T_a=3
# --- 2286.629456281662 seconds ---
# compute SP22 class positivity for T_e=5 and T_a=5
# --- 2292.4577827453613 seconds ---
# compute SP22 class positivity for T_e=5 and T_a=7
# --- 2280.9399898052216 seconds ---
# compute SP22 class positivity for T_e=7 and T_a=3
# --- 2292.5878524780273 seconds ---
# compute SP22 class positivity for T_e=7 and T_a=5
# --- 2279.268509864807 seconds ---

# %%
for T_e in [3,5,7]:
    for T_a in [3,5,7]:
        if T_e == 7 and T_a == 7:
            continue
        start_time = time.time()
        print(f"compute FA21 class positivity for T_e={T_e} and T_a={T_a}")
        compute_class_positivity_fa21(T_e, T_a)
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# compute FA21 class positivity for T_e=3 and T_a=3
# c:\Program Files\Python37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# --- 6019.110571861267 seconds ---
# compute FA21 class positivity for T_e=3 and T_a=5
# --- 5805.805203199387 seconds ---
# compute FA21 class positivity for T_e=3 and T_a=7
# --- 5827.548111438751 seconds ---
# compute FA21 class positivity for T_e=5 and T_a=3
# --- 5877.288133859634 seconds ---
# compute FA21 class positivity for T_e=5 and T_a=5
# --- 5855.057609796524 seconds ---
# compute FA21 class positivity for T_e=5 and T_a=7
# --- 5844.37223649025 seconds ---
# compute FA21 class positivity for T_e=7 and T_a=3
# --- 5831.486994743347 seconds ---
# compute FA21 class positivity for T_e=7 and T_a=5
# --- 6129.1756291389465 seconds ---

# %%
# 37mins
compute_class_positivity_sp22(T_e=3, T_a=3)

# %%
# %%time
pd.read_csv("G:/Data_Peter/classroom_transmission/data/data_sp22/all_students_features_T_e=3_T_a=3_finalized.csv", index_col=0)
# Out:
# Wall time: 412 ms
#                           employee_id_hash  \
# 0       0x0001CEED0A3584312155FD3B695D2EB6
# 1       0x0001CEED0A3584312155FD3B695D2EB6
# 2       0x0001CEED0A3584312155FD3B695D2EB6
# 3       0x0001CEED0A3584312155FD3B695D2EB6
# 4       0x0001CEED0A3584312155FD3B695D2EB6
# ...                                    ...
# 163156  0xFFFE5ADD2F982454AF05B7DBCD6A57BB
# 163157  0xFFFE5ADD2F982454AF05B7DBCD6A57BB
# 163158  0xFFFE5ADD2F982454AF05B7DBCD6A57BB
# 163159  0xFFFE5ADD2F982454AF05B7DBCD6A57BB
# 163160  0xFFFE5ADD2F982454AF05B7DBCD6A57BB
#
#                                 netid_hash academic_plan1 current_gender  \
# 0       0x182BE92DEFC2F7E3C885311242FE3454        ESAG-BS              F
# 1       0x182BE92DEFC2F7E3C885311242FE3454        ESAG-BS              F
# 2       0x182BE92DEFC2F7E3C885311242FE3454        ESAG-BS              F
# 3       0x182BE92DEFC2F7E3C885311242FE3454        ESAG-BS              F
# ...

# %%
# %%time
compute_class_positivity_sp22(T_e=3, T_a=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed eval> in <module>
#
# g:\Data_Peter\classroom_transmission\src\compute_class_positivity.py in compute_class_positivity_sp22(T_e, T_a)
#     371                             (class_positive_history[[str(t) for t in np.arange(hd_notify_reg_time-T_a+1)]]) / (enrollment_count-1)
#     372                         pre_notify_prev_history_2 = daily_class_hours * \
# --> 373                             (class_positive_history[[str(t) for t in np.arange(hd_notify_reg_time-T_a+1, hd_notify_reg_time+1)]] - 1) / (enrollment_count-1)
#     374
#     375                         pre_notify_prev_history = pd.concat([pre_notify_prev_history_1, pre_notify_prev_history_2], axis=1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
# ...

# %%
# %%time
compute_class_positivity_sp22(T_e=3, T_a=7)

# %%
# %%time
compute_class_positivity_sp22(T_e=5, T_a=3)

# %%
# %%time
compute_class_positivity_sp22(T_e=5, T_a=5)

# %%
# %%time
compute_class_positivity_sp22(T_e=5, T_a=7)

# %%
# %%time
compute_class_positivity_sp22(T_e=7, T_a=3)

# %%
# %%time
compute_class_positivity_sp22(T_e=7, T_a=5)
